# %%
import os

# %%
# Create the following paths
for i in [
    'output/1_scraped_data',
    'output/2_processed_data'
]:
    if not os.path.exists(i):
        print(f"Creating relative path: {i}...")
        os.makedirs(i)
    else:
        print(f"Path already exists: {i}")
# Out:
# Path already exists: output/scraped_data
# Path already exists: output/processed_data
